# %%
# Builtin modules
from itertools import chain
import random
import warnings
import sys
import os

# Images
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from PIL import ImageFile
import matplotlib.pyplot as plt
import numpy as np
import cv2

# Deep learning
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Dropout, Lambda
from keras.layers.merge import concatenate
from keras.layers import Input
from keras.models import Model, load_model
from keras import backend as K
from tensorflow.python.util import deprecation
import tensorflow as tf

# Ignore warnings
warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
ImageFile.LOAD_TRUNCATED_IMAGES = True
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# Set the parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = 'data/train/'
TEST_PATH = 'data/test/'

random.seed = np.random.seed = 42

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# ---------------------------------------------------

# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

for n, id_ in enumerate(train_ids):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask
    
# ---------------------------------------------------
    
# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []

for n, id_ in enumerate(test_ids):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:, :, :IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img
    

print("X_train", X_train.shape)
print("Y_train", Y_train.shape)
# Out:
# X_train (33, 128, 128, 3)
# Y_train (33, 128, 128, 1)

# %%
# Define IoU function 
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# WARNING:tensorflow:From c:\users\ronak\.virtualenvs\buildingdetection-jplpw8qy\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 448         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 256)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 128)  131200      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   32832       conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 32)   8224        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 16) 2064        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 16) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 1)  17          conv2d_18[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=50, verbose=1)
checkpointer = ModelCheckpoint('test/model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, 
                    Y_train,
                    validation_split=0.1,
                    batch_size=16,
                    epochs=50,
                    callbacks=[earlystopper, checkpointer])

#Predict on train, val and test
model = load_model('test/model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                      (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# WARNING:tensorflow:From c:\users\ronak\.virtualenvs\buildingdetection-jplpw8qy\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 29 samples, validate on 4 samples
# Epoch 1/50
# 29/29 [==============================] - 5s 172ms/step - loss: 0.7494 - mean_iou: 0.1936 - val_loss: 0.6806 - val_mean_iou: 0.3940
#
# Epoch 00001: val_loss improved from inf to 0.68064, saving model to test/model-dsbowl2018-1.h5
# Epoch 2/50
# 29/29 [==============================] - 3s 87ms/step - loss: 0.5746 - mean_iou: 0.3979 - val_loss: 0.6962 - val_mean_iou: 0.4005
#
# Epoch 00002: val_loss did not improve from 0.68064
# Epoch 3/50
# 29/29 [==============================] - 2s 86ms/step - loss: 0.5051 - mean_iou: 0.3971 - val_loss: 0.7139 - val_mean_iou: 0.4026
#
# Epoch 00003: val_loss did not improve from 0.68064
# Epoch 4/50
# 29/29 [==============================] - 3s 107ms/step - loss: 0.4717 - mean_iou: 0.4014 - val_loss: 0.7467 - val_mean_iou: 0.4117
#
# Epoch 00004: val_loss did not improve from 0.68064
# Epoch 5/50
# 29/29 [==============================] - 3s 93ms/step - loss: 0.4637 - mean_iou: 0.4092 - val_loss: 0.6533 - val_mean_iou: 0.4110
#
# Epoch 00005: val_loss improved from 0.68064 to 0.65331, saving model to test/model-dsbowl2018-1.h5
# Epoch 6/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.4681 - mean_iou: 0.4100 - val_loss: 0.6469 - val_mean_iou: 0.4149
#
# Epoch 00006: val_loss improved from 0.65331 to 0.64693, saving model to test/model-dsbowl2018-1.h5
# Epoch 7/50
# 29/29 [==============================] - 2s 85ms/step - loss: 0.4130 - mean_iou: 0.4145 - val_loss: 0.6813 - val_mean_iou: 0.4179
#
# Epoch 00007: val_loss did not improve from 0.64693
# Epoch 8/50
# 29/29 [==============================] - 2s 84ms/step - loss: 0.4041 - mean_iou: 0.4182 - val_loss: 0.5662 - val_mean_iou: 0.4204
#
# Epoch 00008: val_loss improved from 0.64693 to 0.56620, saving model to test/model-dsbowl2018-1.h5
# Epoch 9/50
# 29/29 [==============================] - 2s 84ms/step - loss: 0.3863 - mean_iou: 0.4204 - val_loss: 0.5427 - val_mean_iou: 0.4247
#
# Epoch 00009: val_loss improved from 0.56620 to 0.54270, saving model to test/model-dsbowl2018-1.h5
# Epoch 10/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.3445 - mean_iou: 0.4241 - val_loss: 0.4746 - val_mean_iou: 0.4288
#
# Epoch 00010: val_loss improved from 0.54270 to 0.47456, saving model to test/model-dsbowl2018-1.h5
# Epoch 11/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.3032 - mean_iou: 0.4302 - val_loss: 0.3607 - val_mean_iou: 0.4338
#
# Epoch 00011: val_loss improved from 0.47456 to 0.36066, saving model to test/model-dsbowl2018-1.h5
# Epoch 12/50
# 29/29 [==============================] - 2s 82ms/step - loss: 0.2901 - mean_iou: 0.4383 - val_loss: 0.3774 - val_mean_iou: 0.4469
#
# Epoch 00012: val_loss did not improve from 0.36066
# Epoch 13/50
# 29/29 [==============================] - 2s 84ms/step - loss: 0.2615 - mean_iou: 0.4506 - val_loss: 0.4490 - val_mean_iou: 0.4574
#
# Epoch 00013: val_loss did not improve from 0.36066
# Epoch 14/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.2530 - mean_iou: 0.4611 - val_loss: 0.3220 - val_mean_iou: 0.4674
#
# Epoch 00014: val_loss improved from 0.36066 to 0.32198, saving model to test/model-dsbowl2018-1.h5
# Epoch 15/50
# 29/29 [==============================] - 2s 86ms/step - loss: 0.2596 - mean_iou: 0.4743 - val_loss: 0.3137 - val_mean_iou: 0.4825
#
# Epoch 00015: val_loss improved from 0.32198 to 0.31369, saving model to test/model-dsbowl2018-1.h5
# Epoch 16/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.2198 - mean_iou: 0.4874 - val_loss: 0.4190 - val_mean_iou: 0.4946
#
# Epoch 00016: val_loss did not improve from 0.31369
# Epoch 17/50
# 29/29 [==============================] - 2s 82ms/step - loss: 0.2136 - mean_iou: 0.4984 - val_loss: 0.3854 - val_mean_iou: 0.5048
#
# Epoch 00017: val_loss did not improve from 0.31369
# Epoch 18/50
# 29/29 [==============================] - 2s 84ms/step - loss: 0.1984 - mean_iou: 0.5089 - val_loss: 0.3146 - val_mean_iou: 0.5154
#
# Epoch 00018: val_loss did not improve from 0.31369
# Epoch 19/50
# 29/29 [==============================] - 2s 82ms/step - loss: 0.1971 - mean_iou: 0.5198 - val_loss: 0.3310 - val_mean_iou: 0.5265
#
# Epoch 00019: val_loss did not improve from 0.31369
# Epoch 20/50
# 29/29 [==============================] - 2s 82ms/step - loss: 0.1801 - mean_iou: 0.5304 - val_loss: 0.3314 - val_mean_iou: 0.5363
#
# Epoch 00020: val_loss did not improve from 0.31369
# Epoch 21/50
# 29/29 [==============================] - 2s 86ms/step - loss: 0.1855 - mean_iou: 0.5399 - val_loss: 0.3317 - val_mean_iou: 0.5464
#
# Epoch 00021: val_loss did not improve from 0.31369
# Epoch 22/50
# 29/29 [==============================] - 3s 87ms/step - loss: 0.1972 - mean_iou: 0.5493 - val_loss: 0.3364 - val_mean_iou: 0.5531
#
# Epoch 00022: val_loss did not improve from 0.31369
# Epoch 23/50
# 29/29 [==============================] - 2s 82ms/step - loss: 0.1678 - mean_iou: 0.5560 - val_loss: 0.3814 - val_mean_iou: 0.5616
#
# Epoch 00023: val_loss did not improve from 0.31369
# Epoch 24/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.1724 - mean_iou: 0.5648 - val_loss: 0.3703 - val_mean_iou: 0.5698
#
# Epoch 00024: val_loss did not improve from 0.31369
# Epoch 25/50
# 29/29 [==============================] - 3s 90ms/step - loss: 0.1548 - mean_iou: 0.5723 - val_loss: 0.3802 - val_mean_iou: 0.5770
#
# Epoch 00025: val_loss did not improve from 0.31369
# Epoch 26/50
# 29/29 [==============================] - 2s 80ms/step - loss: 0.1490 - mean_iou: 0.5791 - val_loss: 0.3688 - val_mean_iou: 0.5835
#
# Epoch 00026: val_loss did not improve from 0.31369
# Epoch 27/50
# 29/29 [==============================] - 2s 80ms/step - loss: 0.1396 - mean_iou: 0.5860 - val_loss: 0.3651 - val_mean_iou: 0.5901
#
# Epoch 00027: val_loss did not improve from 0.31369
# Epoch 28/50
# 29/29 [==============================] - 2s 80ms/step - loss: 0.1353 - mean_iou: 0.5924 - val_loss: 0.2857 - val_mean_iou: 0.5967
#
# Epoch 00028: val_loss improved from 0.31369 to 0.28575, saving model to test/model-dsbowl2018-1.h5
# Epoch 29/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.1328 - mean_iou: 0.5992 - val_loss: 0.5088 - val_mean_iou: 0.6034
#
# Epoch 00029: val_loss did not improve from 0.28575
# Epoch 30/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.1460 - mean_iou: 0.6049 - val_loss: 0.2263 - val_mean_iou: 0.6087
#
# Epoch 00030: val_loss improved from 0.28575 to 0.22625, saving model to test/model-dsbowl2018-1.h5
# Epoch 31/50
# 29/29 [==============================] - 2s 82ms/step - loss: 0.1435 - mean_iou: 0.6110 - val_loss: 0.2449 - val_mean_iou: 0.6148
#
# Epoch 00031: val_loss did not improve from 0.22625
# Epoch 32/50
# 29/29 [==============================] - 2s 80ms/step - loss: 0.1237 - mean_iou: 0.6170 - val_loss: 0.3853 - val_mean_iou: 0.6203
#
# Epoch 00032: val_loss did not improve from 0.22625
# Epoch 33/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.1388 - mean_iou: 0.6221 - val_loss: 0.3033 - val_mean_iou: 0.6248
#
# Epoch 00033: val_loss did not improve from 0.22625
# Epoch 34/50
# 29/29 [==============================] - 2s 80ms/step - loss: 0.1215 - mean_iou: 0.6267 - val_loss: 0.2472 - val_mean_iou: 0.6299
#
# Epoch 00034: val_loss did not improve from 0.22625
# Epoch 35/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.1208 - mean_iou: 0.6319 - val_loss: 0.3872 - val_mean_iou: 0.6351
#
# Epoch 00035: val_loss did not improve from 0.22625
# Epoch 36/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.1304 - mean_iou: 0.6366 - val_loss: 0.2188 - val_mean_iou: 0.6395
#
# Epoch 00036: val_loss improved from 0.22625 to 0.21877, saving model to test/model-dsbowl2018-1.h5
# Epoch 37/50
# 29/29 [==============================] - 3s 88ms/step - loss: 0.1167 - mean_iou: 0.6410 - val_loss: 0.2154 - val_mean_iou: 0.6441
#
# Epoch 00037: val_loss improved from 0.21877 to 0.21540, saving model to test/model-dsbowl2018-1.h5
# Epoch 38/50
# 29/29 [==============================] - 2s 84ms/step - loss: 0.1128 - mean_iou: 0.6457 - val_loss: 0.2099 - val_mean_iou: 0.6488
# Epoch 00038: val_loss improved from 0.21540 to 0.20994, saving model to test/model-dsbowl2018-1.h5
# Epoch 39/50
# 29/29 [==============================] - 3s 93ms/step - loss: 0.1110 - mean_iou: 0.6508 - val_loss: 0.2336 - val_mean_iou: 0.6533
#
# Epoch 00039: val_loss did not improve from 0.20994
# Epoch 40/50
# 29/29 [==============================] - 2s 85ms/step - loss: 0.1120 - mean_iou: 0.6548 - val_loss: 0.2420 - val_mean_iou: 0.6577
#
# Epoch 00040: val_loss did not improve from 0.20994
# Epoch 41/50
# 29/29 [==============================] - 2s 84ms/step - loss: 0.1063 - mean_iou: 0.6593 - val_loss: 0.2567 - val_mean_iou: 0.6617
#
# Epoch 00041: val_loss did not improve from 0.20994
# Epoch 42/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.1064 - mean_iou: 0.6630 - val_loss: 0.2799 - val_mean_iou: 0.6653
#
# Epoch 00042: val_loss did not improve from 0.20994
# Epoch 43/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.1013 - mean_iou: 0.6668 - val_loss: 0.2899 - val_mean_iou: 0.6690
#
# Epoch 00043: val_loss did not improve from 0.20994
# Epoch 44/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.1033 - mean_iou: 0.6706 - val_loss: 0.2394 - val_mean_iou: 0.6728
#
# Epoch 00044: val_loss did not improve from 0.20994
# Epoch 45/50
# 29/29 [==============================] - 2s 80ms/step - loss: 0.1009 - mean_iou: 0.6742 - val_loss: 0.2583 - val_mean_iou: 0.6766
#
# Epoch 00045: val_loss did not improve from 0.20994
# Epoch 46/50
# 29/29 [==============================] - 2s 80ms/step - loss: 0.1025 - mean_iou: 0.6778 - val_loss: 0.2479 - val_mean_iou: 0.6799
#
# Epoch 00046: val_loss did not improve from 0.20994
# Epoch 47/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0962 - mean_iou: 0.6810 - val_loss: 0.2050 - val_mean_iou: 0.6831
#
# Epoch 00047: val_loss improved from 0.20994 to 0.20497, saving model to test/model-dsbowl2018-1.h5
# Epoch 48/50
# 29/29 [==============================] - 3s 88ms/step - loss: 0.0948 - mean_iou: 0.6844 - val_loss: 0.2257 - val_mean_iou: 0.6865
#
# Epoch 00048: val_loss did not improve from 0.20497
# Epoch 49/50
# 29/29 [==============================] - 2s 83ms/step - loss: 0.0964 - mean_iou: 0.6877 - val_loss: 0.2221 - val_mean_iou: 0.6897
#
# Epoch 00049: val_loss did not improve from 0.20497
# Epoch 50/50
# 29/29 [==============================] - 2s 81ms/step - loss: 0.0919 - mean_iou: 0.6907 - val_loss: 0.2014 - val_mean_iou: 0.6927
#
# Epoch 00050: val_loss improved from 0.20497 to 0.20139, saving model to test/model-dsbowl2018-1.h5
# 29/29 [==============================] - 1s 38ms/step
# 4/4 [==============================] - 0s 24ms/step
# 9/9 [==============================] - 0s 19ms/step
